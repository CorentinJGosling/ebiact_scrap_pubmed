# %% [markdown]
# # First title

# %%
import pandas as pd
from Bio import Entrez

# %%
def search(query):
    Entrez.email = 'corentin.gosling@gmail.com'
    handle = Entrez.esearch(db='pubmed',
                            sort='date',
                            retmax='250000',
                            retmode='xml',
                            term=query)
    results = Entrez.read(handle)
    return results

def fetch_details(id_list):
    ids = ','.join(id_list)
    Entrez.email = 'corentin.gosling@gmail.com'
    handle = Entrez.efetch(db='pubmed',
                           retmode='xml',
                           id=ids)
    results = Entrez.read(handle)
    return results

def extract_doi(list_id):
   res = list('no doi')
   for i in range(0, len(list_id)):
      if "10." in list_id[i]:
         res = list_id[i]
   return res

def extract_email(list_id):
   res = list('no contact author')
   for i in range(0, len(list_id)):
      if "@" in list_id[i]['AffiliationInfo'][0]['Affiliation']:  # and "Electronic" in list_id[i]['AffiliationInfo'][0]['Affiliation']:
         res = list_id[i]['AffiliationInfo'][0]['Affiliation']
   return res

# %%
chunk_size = 10000  

studies = search('(autism[tiab] OR ASD[tiab]) AND (intervention*[tiab]) AND (meta-analysis[pt])')
studiesIdList = studies['IdList']

# %%
title_list= []
doi_list= []
pmid_list= []
author1_list= []
authorN_list= []
author_cor_list= []
email_list= []
abstract_list=[]
journal_list = []
pubdate_year_list = []

studies = fetch_details(studiesIdList)

# %%
for chunk_i in range(0, len(studiesIdList), chunk_size):
  print(chunk_i)
  chunk = studiesIdList[chunk_i:chunk_i + chunk_size]
  papers = fetch_details(chunk)
  for i, paper in enumerate (papers['PubmedArticle']):
    # i = 0
    # print(i)
    # paper = papers['PubmedArticle'][0]
    title_list.append(paper['MedlineCitation']['Article']['ArticleTitle'])
    pmid_list.append(paper['MedlineCitation']['PMID'])
    doi_list.append(extract_doi(paper['PubmedData']['ArticleIdList']))
    journal_list.append(paper['MedlineCitation']['Article']['Journal']['Title'])

    try:
     paper['MedlineCitation']['Article']['AuthorList'][0]['AffiliationInfo'][0]['Affiliation']
     author1_list.append(paper['MedlineCitation']['Article']['AuthorList'][0]['ForeName'] + ' ' + paper['MedlineCitation']['Article']['AuthorList'][0]['LastName'] + ' [' + paper['MedlineCitation']['Article']['AuthorList'][0]['AffiliationInfo'][0]['Affiliation'] + ']')
    except:
     author1_list.append("No 1st author recorded")

    last = len(paper['MedlineCitation']['Article']['AuthorList']) - 1
    try:
     paper['MedlineCitation']['Article']['AuthorList'][last]['AffiliationInfo'][0]['Affiliation']
     authorN_list.append(paper['MedlineCitation']['Article']['AuthorList'][last]['ForeName'] + ' ' + paper['MedlineCitation']['Article']['AuthorList'][last]['LastName'] + ' [' + paper['MedlineCitation']['Article']['AuthorList'][last]['AffiliationInfo'][0]['Affiliation'] + ']')
    except:
     authorN_list.append("No last author recorded")
    
    try:
     author_cor_list.append(paper['MedlineCitation']['Article']['AuthorList'])
    except:
     author_cor_list.append("no")
    try:
     email_list.append(extract_email(paper['MedlineCitation']['Article']['AuthorList']))
    except:
     email_list.append("no")


    try:
      abstract_list.append(' '.join(list(map(str, paper['MedlineCitation']['Article']['Abstract']['AbstractText']))))
    except:
      abstract_list.append('No Abstract')

    try:
      pubdate_year_list.append(paper['MedlineCitation']['Article']['Journal']['JournalIssue']['PubDate']['Year'])
    except:
      pubdate_year_list.append('No Data')

# %%
df = pd.DataFrame(list(zip(
    title_list, doi_list, pmid_list, author1_list, authorN_list, abstract_list, journal_list, pubdate_year_list #author_cor_list, email_list, 
    )), 
    columns=[
             'Title', 'doi', 'PMID', 'First author', 'Last author', 'Abstract', 'Journal', 'Year' #'Corresponding author', 'email', 
             ])
df.shape
 
df.to_excel('scrapped.xlsx')
df.head(10)
# Out:
#                                                Title  \
# 0  Comprehensive ABA-based interventions in the t...
# 1  Effects of Equine-Assisted Activities and Ther...
# 2  Melatonin for sleep disorders in people with a...
# 3  In Search of Biomarkers to Guide Interventions...
# 4  Auditory Pitch Perception in Autism Spectrum D...
# 5  Effects of Therapeutic Horseback-Riding Progra...
# 6  Psychological interventions targeting mental h...
# 7  Examining the relationship between cognitive i...
# 8  Clinical risk factors associated with the deve...
# 9  Intensive behavioural interventions based on a...
#
#                             doi      PMID  \
# 0    10.1186/s12888-022-04412-1  36864429
# 1        10.3390/ijerph20032630  36767996
# 2   10.1016/j.pnpbp.2022.110695  36584862
# 3     10.1176/appi.ajp.21100992  36475375
# 4   10.1044/2022_JSLHR-22-00254  36450443
# 5       10.3390/ijerph192114449  36361327
# 6            10.1111/dmcn.15432  36208472
# 7              10.1002/aur.2826  36196666
# 8  10.1016/j.spinee.2022.08.011  36031098
# 9  10.1371/journal.pone.0270833  35972929
#
#                                         First author  \
# 0  Theresa Eckes [Institute of Psychology, Univer...
# 1  Ningkun Xiao [Department of Psychology, Instit...
# 2  Hellen Araujo Nogueira [Center for Biological ...
# 3  Mara Parellada [Department of Child and Adoles...
# 4  Yu Chen [Speech-Language-Hearing Center, Schoo...
# 5  Shihui Chen [Department of Kinesiology, Texas ...
# 6  Kavindri Kulasinghe [Queensland Cerebral Palsy...
# 7  Jiedi Lei [Institute of Psychiatry, Psychology...
# 8  Samuel E Broida [Department of Orthopaedic Sur...
# 9  Robert Hodgson [Centre for Reviews and Dissemi...
#
#                                          Last author  \
# 0  Anne Möllmann [Institute of Psychology, Univer...
# 1  Jingjing Qi [Engineering School of Information...
# 2  Marcos Pereira [Institute of Collective Health...
# 3  Stephan J Sanders [Department of Child and Ado...
# 4  Yang Zhang [Department of Speech-Language-Hear...
# 5  Xiaolei Liu [Chinese Traditional Regimen Exerc...
# 6  Roslyn N Boyd [Queensland Cerebral Palsy and R...
# 7  Matthew J Hollocks [Institute of Psychiatry, P...
# 8                                                 no
# 9  Ann Le Couteur [Population Health Sciences Ins...
#
#                                 Corresponding author  \
# 0  [{'AffiliationInfo': [{'Identifier': [], 'Affi...
# 1  [{'AffiliationInfo': [{'Identifier': [], 'Affi...
# 2  [{'AffiliationInfo': [{'Identifier': [], 'Affi...
# 3  [{'AffiliationInfo': [{'Identifier': [], 'Affi...
# 4  [{'AffiliationInfo': [{'Identifier': [], 'Affi...
# 5  [{'AffiliationInfo': [{'Identifier': [], 'Affi...
# 6  [{'AffiliationInfo': [{'Identifier': [], 'Affi...
# 7  [{'AffiliationInfo': [{'Identifier': [], 'Affi...
# 8  [{'AffiliationInfo': [{'Identifier': [], 'Affi...
# 9  [{'AffiliationInfo': [{'Identifier': [], 'Affi...
#
#                                                email  \
# 0  Institute of Psychology, University of Münster...
# 1  [n, o,  , c, o, n, t, a, c, t,  , a, u, t, h, ...
# 2  Institute of Collective Health, Federal Univer...
# 3  [n, o,  , c, o, n, t, a, c, t,  , a, u, t, h, ...
# 4  [n, o,  , c, o, n, t, a, c, t,  , a, u, t, h, ...
# 5  [n, o,  , c, o, n, t, a, c, t,  , a, u, t, h, ...
# 6  [n, o,  , c, o, n, t, a, c, t,  , a, u, t, h, ...
# 7  [n, o,  , c, o, n, t, a, c, t,  , a, u, t, h, ...
# 8                                                 no
# 9  [n, o,  , c, o, n, t, a, c, t,  , a, u, t, h, ...
#
#                                             Abstract  \
# 0  Many studies display promising results for int...
# 1  Autism spectrum disorder (ASD) has become a cr...
# 2  Melatonin is a potential therapeutic intervent...
# 3  The aim of this study was to catalog and evalu...
# 4  Pitch plays an important role in auditory perc...
# 5  Animal-assisted therapy has become a fast-grow...
# 6  To investigate the efficacy of psychological i...
# 7  Compared to neurotypical peers, autistic adole...
# 8  Cervical fusion for degenerative disorders car...
# 9  The economic and social costs of autism are si...
#
#                                              Journal  Year
# 0                                     BMC psychiatry  2023
# 1  International journal of environmental researc...  2023
# 2  Progress in neuro-psychopharmacology & biologi...  2023
# 3                 The American journal of psychiatry  2023
# 4  Journal of speech, language, and hearing resea...  2022
# 5  International journal of environmental researc...  2022
# 6         Developmental medicine and child neurology  2023
# 7  Autism research : official journal of the Inte...  2022
# 8  The spine journal : official journal of the No...  2023
# 9                                           PloS one  2022
